# %% [markdown]
# # 03 Ridge Lasso
#
# Learning notebook — implement, experiment, and write your takeaway.

# %% [markdown]
# ## Learning objectives
# - Understand the concept
# - Implement it yourself
# - Compare with the standard library
# - Run an experiment
# - Record the result

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Your implementation
#
# TODO: write the implementation here.

# %%
# TODO

# %% [markdown]
# ## Experiment
#
# TODO: change inputs/parameters and observe what happens.

# %%
# TODO

# %% [markdown]
# ## Takeaway
# - What did I learn?
# - What surprised me?
# - What should I review?
